# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabhnahata/pyton_colab/blob/module-1/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#graph
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7,5,3])
y=np.array([5,10,8,1])
plt.plot(x,y,ls=':',color='g')
plt.show()

# %%
#graph2
import matplotlib.pyplot as plt
import numpy as np
xpts=['c','c++','java','python']
ypts=[3,8,1,10]
plt.bar(xpts, ypts)
plt.show()

# %%
#graph3
import matplotlib.pyplot as plt
import numpy as np
x=np.array([6,9,12])
y=np.array([8,10,12])
plt.plot(x,y)
plt.show()
